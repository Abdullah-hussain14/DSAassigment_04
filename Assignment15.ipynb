# %%
import pandas as pd
import sqlite3 as sql

# %%
conn = sql.connect('database.sqlite')
conn

# %%
def sql(q):
    return pd.read_sql_query(q, conn)

# %%
df = sql("SELECT * FROM salaries")
df.head(10)
# Out:
#    Id        EmployeeName                                          JobTitle  \
# 0   1      NATHANIEL FORD    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   3      ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 2   4   CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 3   5     PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 4   6      DAVID SULLIVAN                         ASSISTANT DEPUTY CHIEF II
# 5   7           ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 6   8       DAVID KUSHNER                    DEPUTY DIRECTOR OF INVESTMENTS
# 7   9      MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 8  10  JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 9  11       ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits    TotalPay  TotalPayBenefits  \
# ...

# %%
Q1 = sql("""
SELECT JobTitle,
       AVG(TotalPayBenefits) AS Avg_TotalPayBenefits
FROM salaries	
WHERE JobTitle NOT IN ('Not Provided', 'Not provided')
GROUP BY JobTitle;
""")
Q1
# Out:
#                                             JobTitle  Avg_TotalPayBenefits
# 0                                      ACCOUNT CLERK          44035.664337
# 1                                         ACCOUNTANT          47429.268000
# 2                                  ACCOUNTANT INTERN          29031.742917
# 3                        ACPO,JuvP, Juv Prob (SFERS)          80266.370000
# 4                                      ACUPUNCTURIST          67594.400000
# ...                                              ...                   ...
# 2153                           X-RAY LABORATORY AIDE          52705.880385
# 2154                           X-Ray Laboratory Aide          69521.123200
# 2155  YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS          53632.870000
# 2156                              Youth Comm Advisor          60118.550000
# 2157                                     ZOO CURATOR          66686.560000
#
# [2158 rows x 2 columns]

# %%
Q2 = sql("""
SELECT EmployeeName, JobTitle, OvertimePay
FROM salaries
WHERE OvertimePay > 50000;
""")
Q2
# Out:
#             EmployeeName                                          JobTitle  \
# 0         ALBERT PARDINI                   CAPTAIN III (POLICE DEPARTMENT)
# 1      CHRISTOPHER CHONG              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 2              ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 3         MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 4          ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...                  ...                                               ...
# 2163  Girma-Worku Zeleke                           Parking Control Officer
# 2164        Not provided                                      Not provided
# 2165        Not provided                                      Not provided
# 2166        Not provided                                      Not provided
# 2167        Not provided                                      Not provided
#
#        OvertimePay
# 0        106088.18
# 1         56120.71
# ...

# %%
Q3 = sql("""
SELECT COUNT(DISTINCT EmployeeName) AS unique_employee_count
FROM salaries
WHERE EmployeeName NOT IN ('Not Provided', 'Not provided');
""")
Q3
# Out:
#    unique_employee_count
# 0                 110808

# %%
Q4 = sql("""
SELECT EmployeeName, JobTitle, TotalPayBenefits
FROM salaries
ORDER BY TotalPayBenefits DESC
LIMIT 10;
""")
Q4
# Out:
#            EmployeeName                                        JobTitle  \
# 0        NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1           David Shinn                                  Deputy Chief 3
# 2            Amy P Hart                               Asst Med Examiner
# 3  William J Coaker Jr.                        Chief Investment Officer
# 4        Gregory P Suhr                                 Chief of Police
# 5  Joanne M Hayes-White                          Chief, Fire Department
# 6        Gregory P Suhr                                 Chief of Police
# 7  Joanne M Hayes-White                          Chief, Fire Department
# 8       Ellen G Moffatt                               Asst Med Examiner
# 9        Gary Altenberg                    Lieutenant, Fire Suppression
#
#    TotalPayBenefits
# 0         567595.43
# 1         510732.68
# 2         479652.21
# 3         436224.36
# 4         425815.28
# 5         422353.40
# 6         418019.22
# ...

# %%
Q5 = sql("""
SELECT *
FROM salaries
ORDER BY TotalPayBenefits DESC;
""")
Q5
# Out:
#             Id          EmployeeName  \
# 0            1        NATHANIEL FORD
# 1       110532           David Shinn
# 2       110533            Amy P Hart
# 3       110534  William J Coaker Jr.
# 4        72926        Gregory P Suhr
# ...        ...                   ...
# 148648  148653          Not provided
# 148649  110529      Timothy E Gibson
# 148650  110530        Mark E Laherty
# 148651  110531         David P Kucia
# 148652  148654             Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                                       Deputy Chief 3     129150.01
# 2                                    Asst Med Examiner     318835.49
# 3                             Chief Investment Officer        257340
# 4                                      Chief of Police     319275.01
# ...                                                ...           ...
# ...
